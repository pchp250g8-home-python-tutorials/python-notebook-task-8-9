# %% [markdown]
# Найти площадь описанной трапеции, боковые стороны которой равны 12 и 15 см. и высота 10 см.

# %% [markdown]
# ![Task-8-9](Task-8-9.png)

# %%
from sympy import Eq
from sympy import solve
from sympy import symbols

AB = 12; CD = 15; EF = 10
pb = (AB + CD) / 2
S = pb * EF
print("S =", S)
